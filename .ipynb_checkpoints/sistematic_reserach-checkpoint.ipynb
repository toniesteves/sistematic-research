# %%
import math
from scipy.io import arff
from scipy.stats.stats import pearsonr
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split

# Formatação mais bonita para os notebooks
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (15,5)

# %%
df_research = pd.read_csv('sistematic_research_data.csv',  header=0)
df_research.head()
# Out:
#                                       Document Title  \
# 0  A 95pJ/label Wide-Range Depth-Estimation Proce...
# 1  Implementation Ring Oscillator Physical Unclon...
# 2  FPGA-Based Real-Time Super-Resolution System f...
# 3  An efficient FPGA implementation of HEVC intra...
# 4  Full-HD Accelerated and Embedded Feature Detec...
#
#                                              Authors  \
# 0  L. Chen; Y. Lu; Y. Hiao; B. Yang; W. Chen; C. ...
# 1  R. Pramudita; S. Ramadhan; F. I. Hariadi; A. S...
# 2          Z. He; H. Huang; M. Jiang; Y. Bai; G. Luo
# 3      H. Azgin; A. C. Mert; E. Kalali; I. Hamzaoglu
# 4                L. Kalms; H. Ibrahim; D. G√∂hringer
#
#                                  Author Affiliations  \
# 0  Department of Electrical Engineering, National...
# 1  School of Electrical Engineering and Informati...
# 2                                 NA; NA; NA; NA; NA
# 3  Faculty of Engineering and Natural Sciences, S...
# 4  Technische Universit√°t Dresden, Dresden, Germ...
#
#                                    Publication Title  Date Added To Xplore  \
# 0  2018 IEEE Asian Solid-State Circuits Conferenc...                   NaN
# 1  2018 International Symposium on Electronics an...                   NaN
# 2  2018 IEEE 26th Annual International Symposium ...                   NaN
# 3  2018 IEEE International Conference on Consumer...                   NaN
# 4  2018 International Conference on ReConFigurabl...                   NaN
#
#    Publication_Year Volume  Issue Start Page End Page         ...          \
# 0              2018    NaN    NaN        261      262         ...
# 1              2018    NaN    NaN          1        5         ...
# 2              2018    NaN    NaN        181      188         ...
# 3              2018    NaN    NaN          1        5         ...
# 4              2018    NaN    NaN          1        6         ...
#
#   Mesh_Terms Article Citation Count Reference Count Copyright Year License  \
# 0        NaN                    NaN             4.0            NaN     NaN
# 1        NaN                    NaN            10.0            NaN     NaN
# 2        NaN                    NaN            47.0            NaN     NaN
# 3        NaN                    3.0            16.0            NaN     NaN
# 4        NaN                    NaN            17.0            NaN     NaN
#
#   Online Date Issue Date Meeting Date Publisher Document Identifier
# 0         NaN        NaN          NaN      IEEE    IEEE Conferences
# 1         NaN        NaN          NaN      IEEE    IEEE Conferences
# 2         NaN        NaN          NaN      IEEE    IEEE Conferences
# 3         NaN        NaN          NaN      IEEE    IEEE Conferences
# 4         NaN        NaN          NaN      IEEE    IEEE Conferences
#
# [5 rows x 30 columns]

# %%
df_resource = df_research[['Document Title','Abstract']]
df_resource.shape
# Out:
# (268, 2)

# %%
df_resource[df_resource['Document Title'].str.contains('decoder|decoding|HEVC|deblocking|accelerator|accelerated|neural network|verified in FPGA|rendering|VLSI design|motion estimation|network on chip', case=False)]['Document Title'].size
# df_resource[df_resource['Abstract'].str.contains('accelerator|accelerated|verified in FPGA|rendering', case=False)==False]['Document Title'].size

df_cleaned_researchs = df_resource[((df_resource['Document Title'].str.contains('decoder|decoding|HEVC|deblocking|accelerator|accelerated|neural network|verified in FPGA|rendering|VLSI design|motion estimation|network on chip', case=False)) | (df_resource['Abstract'].str.contains('accelerator|accelerated|verified in FPGA|rendering', case=False))==False)]
df_cleaned_researchs.shape
# Out:
# (212, 2)

# %%
df_cleaned_researchs
# Out:
#                                         Document Title  \
# 0    A 95pJ/label Wide-Range Depth-Estimation Proce...
# 1    Implementation Ring Oscillator Physical Unclon...
# 2    FPGA-Based Real-Time Super-Resolution System f...
# 5    Design of Efficient Cyclic Redundancy Check-32...
# 6    A High Throughput VLSI Architecture for Real-T...
# 7    A 1.1Œºm-Pitch 13.5Mpixel 3D-stacked CMOS imag...
# 9    FPGA implementation of self-reconfigurable fuz...
# 12   An FPGA-Based Implementation of a Multifunctio...
# 13   Self-Interference Cancellation Enabling High-T...
# 14   Reliable and Modeling Attack Resistant Authent...
# 15   Adaptive Self-Interference Cancellation for Fu...
# 16   Rapid Design of Real-Time Image Fusion on FPGA...
# 18      A One-Shot FPGA Based Depth Acquisition System
# 19   A proposal for a SoC FPGA-based image processi...
# 21   Live Streaming of Uncompressed HD and 4K Video...
# 23   NIPM-sWMF: Towards Efficient FPGA Design for H...
# 25   FPGA-Based Real Time Embedded Hough Transform ...
# 26   A High Performance FPGA-Based Architecture for...
# 28   Real-time depth map processor for offset apert...
# 29   Real-Time Emulation of Multiple NAND Flash Cha...
# 30                      PAFD: Phased Array Full-Duplex
# 32   A Fully Digital Physical Unclonable Function B...
# 34   FPGA-Based Hardware Implementation of Real-Tim...
# 35   Hardware Architecture Implemented on FPGA for ...
# 38   A Reconfigurable Fractional Interpolation Hard...
# 39   A Low Power Versatile Video Coding (VVC) Fract...
# 42   Implementing and Parallelizing Real-time Lane ...
# 43   FPGA-Based Hardware Design for Scale-Invariant...
# 44   Exploiting All Programmable SoCs in Neural Sig...
# 47   Bimodal Oscillation as a Mechanism for Autonom...
# ..                                                 ...
# 237  SCOM: Spatiotemporal Constrained Optimization ...
# 238  DAC-Less and DSP-Free 112 Gb/s PAM-4 Transmitt...
# 239  Hazard-evaluation-oriented moving horizon para...
# 240          Software Defined Radio for Communications
# 241            High Dynamic Range Fluorescence Imaging
# 243  Autonomous Driving in the Curriculum of Comput...
# 244  Hardware implementation of the Gaussian Mixtur...
# 245  Embedded System for Motion Control of an Omnid...
# 246  Local Binary Pattern Circuit Generator With Ad...
# 247  A 46.1 fps Global Matching Optical Flow Estima...
# 248  WPA-WPA2 PSK Cracking Implementation on Parall...
# 249  A 1.2-V 108.9-dB A-Weighted DR 101.4-dB SNDR A...
# 250                Fire Sensing Technologies: A Review
# 251  A Simplified PWM Strategy for Three-Level Conv...
# 252  Electrical Drives with Active Rectifiers Conne...
# 253  Analog Radio-over-Fiber Solutions for 5G Commu...
# 254              EE4: Industry Showcase [13 abstracts]
# 255                                    List of Authors
# 256  2018 Index IEEE Transactions on Circuits and S...
# 257                                         Paper List
# 258                                      EMBC 2018 TOC
# 259                                           Schedule
# 260                      ReConFig 2018 Papers by Track
# 261                                  Table of Contents
# 262                                  Table of contents
# 263                                     List of Papers
# 264                           IMPACT 2018 Author Index
# 265                                  Table of contents
# 266                        Tuesday Morning Sessions M1
# 267                                  Table of contents
#
#                                               Abstract
# 0    High-resolution and wide-range depth maps are ...
# 1    This paper is describing the implementation an...
# 2    The market benefits from a barrage of Ultra Hi...
# 5    In Data Integrity, Cyclic Redundancy Check (CR...
# 6    Guided image filtering (GIF) has been applied ...
# 7    Slow-motion video is a desirable feature for s...
# 9    Nowadays, new system design requirements are i...
# 12   To protect radar receivers and to facilitate s...
# 13   In-band full-duplex (FD) wireless communicatio...
# 14   Field programmable gate array (FPGA) is a pote...
# 15   Recent experimental results show that full-dup...
# 16   During the process of implementing a parameter...
# 18   This paper introduces a field-programmable gat...
# 19   The current robots follow clear, repetitive an...
# 21   Taming the Terahertz waves (100 GHz-10 THz) is...
# 23   Large disparity stereo matching is critical to...
# 25   Hough Transform is a widely used shape-based a...
# 26   Future video coding (FVC) will be the next gen...
# 28   This paper presents a Offset Aperture (OA) bas...
# 29   A modular and versatile FPGA-based platform, d...
# 30   We present the design and implementation of PA...
# 32   Turnkey solutions that combine energy-efficien...
# 34   Optical flow calculation algorithms are hard t...
# 35   This paper presents a new hardware architectur...
# 38   Fractional interpolation is one of the most co...
# 39   Fractional interpolation in Versatile Video Co...
# 42   Lane detection is a cardinal functionality in ...
# 43   This paper proposes a novel hardware design me...
# 44   Microelectrode array (MEA) systems with up to ...
# 47   Physical unclonable functions (PUFs) leveragin...
# ..                                                 ...
# 237  This paper presents a novel model for video sa...
# 238  Four-level pulse amplitude modulation (PAM-4) ...
# 239  Prompted by emerging developments in connected...
# 240  Software Defined Radio (SDR) has evolved in th...
# 241  Fluorescence acquisition and image display ove...
# 243  The need for educated personnel in automotive ...
# 244  The following topics are dealt with: medical i...
# 245  In this paper, an embedded system for motion c...
# 246  In the field of computer vision, local binary ...
# 247  A real-time global matching optical flow estim...
# 248  Today, WLANs are the most outstanding systems ...
# 249  Along with the trend to reduce the power consu...
# 250  The progress on fire sensing technologies has ...
# 251  Presently, the neutral-point potential offset ...
# 252  The paper presents analysis of active rectifie...
# 253  Current research efforts on 5G RAN strongly fo...
# 254  Provides an abstract for each of the 13 presen...
# 255  Presents an index of the authors whose article...
# 256  This index covers all technical items - papers...
# 257  Presents the table of contents/splash page of ...
# 258  Presents the table of contents/splash page of ...
# 259  Provides a schedule of conference events and a...
# 260  Provides a schedule of conference events and a...
# 261  Presents the table of contents/splash page of ...
# 262  Presents the table of contents/splash page of ...
# 263          Future State Visualization in Power Grid.
# 264  Presents an index of the authors whose article...
# 265  Presents the table of contents/splash page of ...
# 266  Renewable energy sources in power systems, dis...
# 267  Presents the table of contents/splash page of ...
#
# [212 rows x 2 columns]
